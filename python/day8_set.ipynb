# %% [markdown]
# ## Set
#
# Set are used to store multiple values in a single variable. Set are created using cruly braces{} and end function set().
#
# key :
# 1. Sets do not maintain order.
# 2. Sets do not allow duplicate values.
# 3. sets do not support indexing
# 4. Elemention a set must be immutable.
